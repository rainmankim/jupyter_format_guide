# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span style='background :white' >    <span style='color:navy'><u> Jupyter Notebook Shortcut & Formatting Guide  </u> </span>     </span>
# _Click on relevant items for quick navigation_
#
# - [Essential Keyboard Shortcuts](#key_shortcuts)
#     - [EDIT Mode Keyboard Shortcuts](#edit_mode_shortcuts)
#     - [COMMAND Mode Keyboard Shortcuts](#command_mode_shortcuts)
#
# ---
# - [How Jupyter Markdown Works](#overview)
# ---
# - [Markdown Essential Formatting](#essential)
#     - [Headings](#headings)
#         - [Markdown method](#headings_markdown)
#         - [HTML method](#headings_html)
#     - [Line breaks](#linebreaks)
#         - [Markdown method](#linebreaks_markdown)
#         - [HTML method](#linebreaks_html)
#     - [Emphasis(bold, underline, italics, strikethrough)](#emphasis)
#         - [Markdown method](#emphasis_markdown)
#         - [HTML method](#emphasis_html)
#     - [Font/background Colors](#font_background_color)
#         - [Font Color](#font_color)
#         - [Background Color](#background_color)
#     - [Horizontal Line](#horizontal_line)
#         - [Markdown method](#horizontal_markdown)
#         - [HTML method](#horizontal_html)
#     - [List](#list)
#         - [Ordered list](#ordered_list)
#             - [Markdown method](#ordered_list_markdown)
#             - [HTML method](#ordered_list_html)
#         - [Unordered list](#unordered_list)
#             - [Markdown method](#unordered_list_markdown)
#             - [HTML method](#unordered_list_html)
#     - [Image](#image)
#         - [Method 1—Direct Image Insertion](#image_method1)
#         - [Method 2—Directory Image Insertion](#image_method2)
#         - [Method 3—Web Image Insertion](#image_method3)
# ---
# - [Markdown Advanced Formatting](#advanced)
#     - [Blockquote](#blockquote)
#         - [Markdown method](#blockquote_markdown)
#         - [HTML method](#blockquote_html)
#     - [Nested Blockquote](#nestedblockquote)
#         - [Markdown method](#nestedblockquote_markdown)
#         - [HTML method](#nestedblockquote_html)
#     - [Code blocks](#codeblock)
#         - [Markdown method](#codeblock_markdown)
#     - [Table](#tables)
#         - [Markdown method](#nestedblockquote_markdown)
#         - [HTML method](#nestedblockquote_html)
#     - [Colored Box](#colorbox)
#     - [External Links](#external_links)
#         - [Markdown method](#external_links_markdown)
#         - [HTML method](#external_links_html)
#     - [Internal Links](#internal_links)
# - [LaTex](#latex)
#     - [Greek letters](#greek_letters)
#
# ---
# - [Micro Tips](#tips)
#     - [Backslash Escape](#backslash_escape)
# - [Extra Tip](#tip_2)
#     - [Measure Runtime](#measure_runtime)

# %% [markdown]
# ***
# # <span style='background :white' >   <span style='color:darkblue'> <u> Essential Keyboard Shortcuts </span></span> <a id='key_shortcuts'>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b><u>Two Modes in Jupyter</u></b>
#
# - EDIT mode: when cursor is blinking inside codeblock
# - COMMAND mode: when cursor is NOT blinking inside codeblock

# %% [markdown]
# ## <span style='background :navy' >    <span style='color:white'> Edit Mode Keyboard Shortcuts   </span>     </span> <a id='edit_mode_shortcuts'>

# %% [markdown]
# Edit Mode Example
#
# ![edit_mode.gif](attachment:edit_mode.gif)

# %% [markdown]
# - ```Ctrl + Enter``` : Run current cell
# - ```Shift + Enter``` : Run current cell and move to next cell
# - ```Alt + Enter``` : Run current cell and insert a cell
# - ```Esc``` : Transition from EDIT Mode to COMMAND Mode

# %% [markdown]
# ## <span style='background :navy' >    <span style='color:white'> Command Mode Shortcuts   </span>     </span> <a id='command_mode_shortcuts'>

# %% [markdown]
# - ```Ctrl + Enter``` : Run current cell
# - ```Shift + Enter``` : Run current cell and move to next cell
# - ```Alt + Enter``` : Run current cell and insert a cell
# - ```Enter``` :  Transition from COMMAND Mode to EDIT Mode
# - ```up down key```: Navigate up and down
# - ```space``` : Scroll down
# - ```shit + space``` : Scroll up
# - ```b```: Insert a new cell below current cell
# - ```a```:  Insert a new cell above current cell
# - ```dd```: Delete current cell
# - ```z``` : Undo cell deletion
# - ```c``` : Copy current cell
# - ```x``` : Cut current cell
# - ```v``` : Paste current cell
# - ```m``` : Change cell to Markdown
# - ```y``` : Change cell to Code
# - ```p``` : Open up Command Palette
# - ```h``` : See full list of keyboard shortcuts

# %% [markdown]
# ***
# # <span style='background :white' >    <span style='color:green'> <u> How Jupyter Markdown works  </span></span> <a id='overview'>
#
# <div class="alert alert-block alert-success">
# <b>Just Need to know two things:</b>
# <li> Markdown: Easy, simple and optimized for decoration. Can be considered an easy version of HTML.
# <li> HTML: More sophisticated and allows complex decoration.
# </div>

# %% [markdown]
# ***
# # <span style='background :white' >    <span style='color:green'> <u> Markdown Essential Formatting  </span></span> <a id='essential'>

# %% [markdown]
# ## <span style='background :green' >    <span style='color:white'> Headings</span>     </span> <a id='headings'>

# %% [markdown]
# #### <font color = green> Markdown method <a id='headings_markdown'>

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# ##### Heading 5

# %% [markdown]
# <h4 style="color:green">HTML method</h4> <a id='headings_html'>

# %% [markdown]
# <h1> Heading 1
# <h2> Heading 2
# <h3> Heading 3
# <h4> Heading 3
# <h5> Heading 3

# %% [markdown]
# ## <span style='background :green' >    <span style='color:white'> Line breaks </span>     </span> <a id='linebreaks'>

# %% [markdown]
# #### <font color = green> Markdown method <a id='linebreaks_markdown'>

# %% [markdown]
# I simply need two or more spaces for next line
# This is next line

# %% [markdown]
# <h4 style="color:green">HTML method</h4> <a id='linebreaks_html'>

# %% [markdown]
# <p> I need to input "br" for next line. <br> This is next line </p>

# %% [markdown]
# ## <span style='background :green' >    <span style='color:white'> Mark Emphasis</span>     </span> <a id='emphasis'>

# %% [markdown]
# #### <font color = green> Markdown version <a id='emphasis_markdown'>
# <font color = red> Underline only works when HTML Tag is used

# %% [markdown]
# **Bold syntax 1**
# __Bold syntax 2__
#
# _Italics syntax 1_
# *Italics syntax 1*
#
# ~~Strikethrough~~

# %% [markdown]
# <h4 style="color:green">HTML version</h4> <a id='emphasis_html'>

# %% [markdown]
# <b> Bold syntax 1 </b>
# <strong> Bold syntax 2  </strong>
#
# <i> Italics syntax 1</i>
# <em> Italics syntax 2</em>
#
# <strike>Strikethrough</strike>
#
# <u> Underline is only possible with HTML tag!!!</u>

# %% [markdown]
# ## <span style='background :green' >    <span style='color:white'> Font/Background Color   </span>     </span> <a id='font_background_color'>

# %% [markdown]
# #### <font color = green> Font Color<a id='font_color'>

# %% [markdown]
# <span style='color:Blue'> This is blue.  </span>
# <font color = red> This is red  </font>

# %% [markdown]
# #### <font color = green> Background Color <a id='background_color'>

# %% [markdown]
# <span style='background :yellow' > This is yellow background </span>

# %% [markdown]
# ## <span style='background :green' >    <span style='color:white'> Horizontal Line   </span>     </span> <a id='horizontal_line'>

# %% [markdown]
# #### <font color = green> Markdown version <a id='horizontal_markdown'>

# %% [markdown]
# ---

# %% [markdown]
# <h4 style="color:green">HTML version</h4> <a id='horizontal_html'>

# %% [markdown]
# <hr>

# %% [markdown]
# ## <span style='background :green' >    <span style='color:white'> List </span>     </span> <a id='list'>

# %% [markdown]
# #### <span style='background :green' >    <span style='color:white'> Ordered List </span>     </span> <a id='ordered_list'>

# %% [markdown]
# #### <font color = green> Markdown version <a id='ordered_list_markdown'>

# %% [markdown]
# 1. Apple
#     1. is Red (Use Tab or multiple Spaces for indentation)
#     2. and delicious
# 2. Banana
#     1. is long
#     2. and delicious
#         3. and cheap

# %% [markdown]
# <h4 style="color:green">HTML version</h4> <a id='ordered_list_html'>

# %% [markdown]
# <ol>
#  <li>Apple</li>
#  <li>Banana</li>
#  <li>Coconut</li>
#     <ol>
#         <li>coconut 1</li>
#         <li>coconut 2</li>
#     </ol>
# </ol>

# %% [markdown]
# #### <span style='background :green' >    <span style='color:white'> Unordered List </span>     </span> <a id='unordered_list'>

# %% [markdown]
# #### <font color = green> Markdown version <a id='unordered_list_markdown'>

# %% [markdown]
# - item 1
# + item 2
# * item 3

# %% [markdown]
# <h4 style="color:green">HTML version</h4> <a id='unordered_list_html'>

# %% [markdown]
# <ul>
#  <li>apple</li>
#  <li>banana</li>
#  <li>coconut</li>
#     <ul>
#     <li> coconut 1
#     <li> coconut 2
#     </ul>
#  </ul>

# %% [markdown]
# ## <span style='background :green' >    <span style='color:white'> Image </span>     </span> <a id='image'>

# %% [markdown]
# #### <font color = green> Method 1—Direct Image Insertion<a id='image_method1'>

# %% [markdown]
# <img src="images\direct_image_insert.png" alt="Direct image insert" >

# %% [markdown]
# ![apple.jfif](attachment:apple.jfif)
#
# ```You can change the width```
# <div>
# <img src="attachment:apple.jfif" width="200"/>
# </div>

# %% [markdown]
# #### <font color = green> Method 2—Directory Image Insertion <a id='image_method2'>

# %% [markdown]
# <img src="images/apple.jfif" alt="brain" width=100>

# %% [markdown]
# #### <font color = green> Method 3—Web Image Insertion<a id='image_method3'>

# %% [markdown]
# <img src="https://th.bing.com/th/id/OIP.UtQu731e3WVIJ67kUFIhxwHaHa?w=183&h=183&c=7&r=0&o=5&pid=1.7" alt="coconut" width=100>

# %% [markdown]
# ***
# # <span style='background :white' >    <span style='color:purple'> <u> Markdown Advanced Formatting</span></span> <a id='advanced'>

# %% [markdown]
# ## <span style='background :purple' >    <span style='color:white'> Blockquote </span>     </span> <a id='blockquote'>

# %% [markdown]
# #### <font color = purple> Markdown version <a id='blockquote_markdown'>

# %% [markdown]
# > This is blockquote. Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum

# %% [markdown]
# <h4 style="color:purple">HTML version</h4> <a id='blockquote_html'>

# %% [markdown]
# <blockquote> This is blockquote. Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum

# %% [markdown]
# ## <span style='background :purple' >    <span style='color:white'> Nested Blockquote </span>     </span> <a id='nestedblockquote'>

# %% [markdown]
# #### <font color = purple> Markdown version <a id='nestedblockquote_markdown'>

# %% [markdown]
# > This is level 1
# >> This is level 2
# >>> This is level 3

# %% [markdown]
# <h4 style="color:purple">HTML version</h4> <a id='nestedblockquote_html'>

# %% [markdown]
# <blockquote>
# <p>This is LEVEL 1</p>
# <blockquote>
# <p>This is LEVEL 2</p>
# <blockquote>
# <p>This is LEVEL 3</p>
# </blockquote>
# </blockquote>
# </blockquote>

# %% [markdown]
# ## <span style='background :purple' >    <span style='color:white'> Code Blocks </span>     </span> <a id='codeblock'>

# %% [markdown]
# #### <font color = purple> Markdown version <a id='codeblock_markdown'>
# <font color = red> In HTML, codeblocks are complex, and hence, we will skip.

# %% [markdown]
# ```python
# ## Start with ```
# i = 0
# while i<3:
#     print('Apple')
#     i+=1
# ```

# %% [markdown]
# ~~~python
# ## Start with ~~~
# for i in ['Apple', 'Banana']:
#     print(i)
# ~~~

# %% [markdown]
# ```apple banana coconuts```

# %% [markdown]
# ## <span style='background :purple' >    <span style='color:white'> Table </span>     </span> <a id='tables'>

# %% [markdown]
# #### <font color = purple> Markdown version <a id='tables_markdown'>

# %% [markdown]
# | Id | Fruits   | Price |
# |--- |----------| ------|
# | 01 | APPLE    | \$111 |
# | 02 | BANANA   | \$222 |
# | 03 | COCONUT  | \$333 |

# %% [markdown]
# <h4 style="color:purple">HTML version</h4> <a id='tables_html'>

# %% [markdown]
# <table>
#   <tr>
#     <th>ID     </th>
#     <th>Fruits  </th>
#     <th>Color</th>
#   </tr>
#   <tr>
#     <td>01</td>
#     <td>Apple</td>
#     <td>Red</td>
#   </tr>
#   <tr>
#     <td>02</td>
#     <td>Banana</td>
#     <td>Yellow</td>
#   </tr>
# </table>

# %% [markdown]
# ## <span style='background :purple' >    <span style='color:white'> Colored Boxes </span>     </span> <a id='colorbox'>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Blue:</b> Blue Sky
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Yellow:</b> Yellow Banana
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Green:</b> Green Tree
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Red:</b> Red Apple
# </div>

# %% [markdown]
# ## <span style='background :purple' >    <span style='color:white'> External Link</span>     </span> <a id='external_links'>

# %% [markdown]
# #### <font color = purple> Markdown version <a id='external_links_markdown'>

# %% [markdown]
# https://www.google.com
#
# [Click this](https://www.google.com)
#
# See the right [Click this feat mouseover text](https://www.google.com "do you see this?")

# %% [markdown]
# <h4 style="color:purple">HTML version</h4> <a id='external_links_html'>

# %% [markdown]
# <a href="https://www.google.com">https://www.google.com</a>
#
# <a href="https://www.google.com">Click this</a>
#
# See the right <a href="https://www.google.com" title=”Google”>Click this feat mouseover text</a>

# %% [markdown]
# ## <span style='background :purple' >    <span style='color:white'> Internal Link</span>     </span> <a id='internal_links'>

# %% [markdown]
# - [teleport1](#teleport_1)
# - [teleport2](#teleport_2)

# %% [markdown]
# ***
# # <span style='background :white' >    <span style='color:chocolate'><u> Latex</span>     </span> <a id='latex'>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b><u>Two Modes</u></b>
#
# - In Juypter Notebook, you can use LateX (a markup language) for mathematical symbols and formulas
# - \$ Insert Latex here \\$
# - \\$\\$ Centralize Latex\\$\\$
# - LateX is extensive. Please refer to below links for more details.
#     - https://oeis.org/wiki/List_of_LaTeX_mathematical_symbols
#     - https://towardsdatascience.com/write-markdown-latex-in-the-jupyter-notebook-10985edb91fd
# </div>

# %% [markdown]
# ## <span style='background :chocolate' >    <span style='color:white'> Greek letters </span>     </span> <a id='greek_letters'>

# %% [markdown]
# <table>
#   <tr>
#     <th>Symbol     </th>
#     <th>Latex  </th>
#     <th>Symbol</th>
#     <th>Latex</th>
#   </tr>
#   <tr>
#     <td>$\alpha$</td>
#     <td>\alpha</td>
#     <td>$\nu$</td>
#     <td>\nu</td>
#   </tr>
#   <tr>
#     <td>$\beta$</td>
#     <td>\beta</td>
#     <td>$\xi \ \Xi$</td>
#     <td>\xi \Xi</td>
#   </tr>
#   <tr>
#     <td>$\gamma \ \Gamma$</td>
#     <td>\gamma \Gamma</td>
#     <td>$\omicron$</td>
#     <td>\omicron</td>
#   </tr>
#   <tr>
#     <td>$\delta \ \ \Delta$</td>
#     <td>\delta \Delta</td>
#     <td>$\Pi \ \pi \ \varpi$</td>
#     <td>\Pi, \pi and \varpi</td>
#   </tr>
#   <tr>
#     <td>$\epsilon \ \varepsilon$</td>
#     <td>\epsilon \varepsilon</td>
#     <td>$\rho \ \varrho$</td>
#     <td>\rho and \varrho</td>
#   </tr>
#   <tr>
#     <td>$\zeta$</td>
#     <td>\zeta</td>
#     <td>$\Sigma \ \sigma \ \varsigma$</td>
#     <td>\Sigma, \sigma and \varsigma</td>
#   </tr>
#   <tr>
#     <td>$\eta$</td>
#     <td>\eta</td>
#     <td>$\tau$</td>
#     <td>\tau</td>
#   </tr>
#   <tr>
#     <td>$\theta \ \ \Theta \ \vartheta$</td>
#     <td>\theta \Theta \vartheta</td>
#     <td>$\Upsilon \ \upsilon$</td>
#     <td>\Upsilon and \upsilon</td>
#   </tr>
#   <tr>
#     <td>$\iota$</td>
#     <td>\iota</td>
#     <td>$\Phi \ \phi \ \varphi$</td>
#     <td>\Phi, \phi and \varphi</td>
#   </tr>
#   <tr>
#     <td>$\kappa \ \varkappa$</td>
#     <td>\kappa \varkappa</td>
#     <td>$\chi$</td>
#     <td>\chi</td>
#   </tr>
#   <tr>
#     <td>$\lambda \ \Lambda$</td>
#     <td>\lambda \Lambda</td>
#     <td>$\Psi \ \psi$</td>
#     <td>\Psi and \psi</td>
#   </tr>
#   <tr>
#     <td>$\mu$</td>
#     <td>\mu</td>
#     <td>$\Omega \ \ \omega$</td>
#     <td>\Omega and \omega</td>
#   </tr>
# </table>

# %% [markdown]
# ***
# # <span style='background :white' >    <span style='color:black'> <u> Micro Tips</span></span> <a id='tips'>

# %% [markdown]
# ## <span style='background :gray' >    <span style='color:white'> Backslash Escape </span>     </span> <a id='backslash_escape'>

# %% [markdown]
# If you need to use special characters such as \#, you must use \\ followed by special character.

# %% [markdown]
# ***
# # <span style='background :white' >    <span style='color:black'> <u> Extra Tip  </span></span> <a id='tip_2'>

# %% [markdown]
# ## <span style='background :gray' >    <span style='color:white'> Measure Runtime </span>     </span> <a id='measure_runtime'>

# %%
# %%time
counter =0
for i in range(1, 12345678):
    counter+=1
# Out:
# CPU times: total: 609 ms
# Wall time: 760 ms
